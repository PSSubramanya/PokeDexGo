# %%
import requests

def download_raids_json(url, save_path):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print("research.json downloaded successfully!")
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch raids.json: {e}")

if __name__ == "__main__":
    url = "https://raw.githubusercontent.com/bigfoott/ScrapedDuck/data/research.json"
    save_path = "research.json"
    download_raids_json(url, save_path)
# Out:
# research.json downloaded successfully!

# %%
import json

# Path to the existing JSON file
existing_json_file = '/content/research.json'

# Read the original JSON data from the file
with open(existing_json_file, 'r') as file:
    original_data = json.load(file)

# Create a new JSON object with the "data" wrapper
new_data = {"data": original_data}

# Write the new JSON object back to the file
with open(existing_json_file, 'w') as file:
    json.dump(new_data, file, indent=4)

print("Added 'data' wrapper to the JSON file.")
# Out:
# Added 'data' wrapper to the JSON file.

# %%
import requests
import json

url = "https://getpantry.cloud/apiv1/pantry/b45d3e57-17a6-498d-8aec-b8173408efb4/basket/fieldResearch"

# Load data from raids.json file
with open('/content/research.json') as f:
    payload = json.load(f)

# Convert the payload to a JSON string
payload_json = json.dumps(payload)

headers = {
    'Content-Type': 'application/json'
}

response = requests.post(url, headers=headers, data=payload_json)

print(response.text)
# Out:
# Your Pantry was updated with basket: fieldResearch!
